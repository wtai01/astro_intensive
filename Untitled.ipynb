# %%
# %matplotlib inline
from astropy.io import fits
from astropy import units as u
import os
import pickle as pickle
from astropy.stats import sigma_clipped_stats
from astropy.time import Time
import pandas as pd
from tabulate import tabulate
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
out_13co2=pickle.load(open(r"C:\Users\taiwe\Documents\13co2_1e19_500_1au2_1pc_irs.p",'rb'))
fig=plt.figure(1,figsize=(18,10))
ax1=fig.add_subplot(111)
ax1.plot(out_13co2['spectrum']['wave'],out_13co2['spectrum']['convolflux'])

ax1.set_xlabel('Wavelength (um)',fontsize=18)
ax1.set_ylabel('13CO2 Flux',fontsize=18)
# Out:
# Text(0, 0.5, '13CO2 Flux')

# %%
HTLUP = fits.open(r"C:\Users\taiwe\Documents\HTLUP_c2d_SH_final.fits")

# %%
# Out:
# Filename: C:\Users\taiwe\Documents\HTLUP_c2d_SH_final.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     21   1R x 2C   [883E, 883D]

# %%
HTLUP[0].header
# Out:
# SIMPLE  =                    T /Primary Header created by MWRFITS v1.4
# BITPIX  =                    8 /
# NAXIS   =                    0 /
# EXTEND  =                    T /Extensions may be present

# %%
plt.imshow(data, cmap='gray')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 plt.imshow(data, cmap='gray')
#       2 plt.colorbar()
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# ...

# %%
out_12co2=pickle.load(open(r"C:\Users\taiwe\Documents\co2_1e19_500_1au2_1pc_irs.p",'rb'))
fig=plt.figure(1,figsize=(18,10))
ax1=fig.add_subplot(111)
ax1.plot(out_12co2['spectrum']['wave'],out_12co2['spectrum']['convolflux'])

ax1.set_xlabel('Wavelength (um)',fontsize=18)
ax1.set_ylabel('12CO2 Flux',fontsize=18)
# Out:
# Text(0, 0.5, '12CO2 Flux')
